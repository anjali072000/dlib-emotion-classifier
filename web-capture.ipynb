# %%
import cv2
import matplotlib.pyplot as plt
#cap.release()
#cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(1)

# %%
ret, frame = cap.read()

# %%
ret
# Out:
# True

# %%
plt.imshow(frame)

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
cap.release()
